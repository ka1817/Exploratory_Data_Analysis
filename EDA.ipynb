# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\saipr\\Downloads\\supermarket_sales - Sheet1.csv")

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
#show top rows of dataset
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
#Display last 5 rows
df.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22     Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33     Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28     Cash
#
# ...

# %%
#Random 5 rows from dataset
df.sample(5)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 490  686-41-0932      B   Mandalay        Normal  Female
# 266  808-65-0703      C  Naypyitaw        Normal    Male
# 367  468-88-0009      A     Yangon        Member    Male
# 945  489-82-1237      A     Yangon        Normal  Female
# 522  609-81-8548      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity  Tax 5%    Total       Date  \
# 490     Fashion accessories       34.70         2   3.470   72.870  3/13/2019
# 266      Home and lifestyle       35.47         4   7.094  148.974  3/14/2019
# 367      Home and lifestyle       65.94         4  13.188  276.948  3/24/2019
# 945  Electronic accessories       93.88         7  32.858  690.018   1/5/2019
# 522      Home and lifestyle       37.44         6  11.232  235.872   2/6/2019
#
#       Time      Payment    cogs  gross margin percentage  gross income  Rating
# ...

# %%
#Find shape of our dataset
df.shape
# Out:
# (1000, 17)

# %%
#check null values in dataset
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
#Get  information about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
#Get overall statistics about the dataset
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
#Univarient Analysis
#Find Aggregate sales amoung Branches.(Categorical Column)
df.head(2)
sns.countplot(x=df['Branch'])
# Out:
# <Axes: xlabel='Branch', ylabel='count'>

# %%
total_sales_amoung_branchs=df.groupby('Branch')['Branch'].count()
total_sales_amoung_branchs
# Out:
# Branch
# A    340
# B    332
# C    328
# Name: Branch, dtype: int64

# %%
df['Branch'].value_counts().plot(kind="pie",autopct="%1.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df['Branch'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Branch'>

# %%
#Find the most popular payment method used by customers

popular_payment_method=df.groupby('Payment')['Payment'].count()
popular_payment_method
# Out:
# Payment
# Cash           344
# Credit card    311
# Ewallet        345
# Name: Payment, dtype: int64

# %%
df.head()
sns.countplot(x=df['Payment'],color='brown')
# Out:
# <Axes: xlabel='Payment', ylabel='count'>

# %%
df['Payment'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Payment'>

# %%
#Find the distributions of customer Ratings.(Numerical columns)
#We can use Dist plot and Box plot for numerical columns
df.head()
sns.distplot(df['Rating'])
# Out:
# C:\Users\saipr\AppData\Local\Temp\ipykernel_24648\1551303357.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Rating'])
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
#Find the Distribution of cost of goods sold(Numeric column)
df.head()
sns.distplot(df['cogs'])
# Out:
# C:\Users\saipr\AppData\Local\Temp\ipykernel_24648\1719500324.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['cogs'])
# <Axes: xlabel='cogs', ylabel='Density'>

# %%
df['cogs'].skew()
#output is positive means  data is right skewe if output is negitive it is left skewed ,if output is 0 our data is normally distributed
# Out:
# 0.8925698049581418

# %%
sns.boxplot(df['cogs'])
#This is one of the method for outlier detection
# Out:
# <Axes: ylabel='cogs'>

# %%
#Bivariant Analysis/Multivariate Analysis
#1.Does The cost of goods sold affect the ratings that the customers Provide?(Numerical columns)
#for both numerical columns
sns.scatterplot(x='cogs', y='Rating', data=df)
# Out:
# <Axes: xlabel='cogs', ylabel='Rating'>

# %%
#Does gross income affect the ratings that the customers provide?(Numerical-Numerical)
sns.scatterplot(x='gross income',y='Rating',data=df)
# Out:
# <Axes: xlabel='gross income', ylabel='Rating'>

# %%
#Find the most profitable Branch as per gross income.(Numerical-categorical)
sns.barplot(x='Branch',y='gross income',data=df)
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %%
df1=df.groupby('Branch',as_index=False)['gross income'].max()
df1
# Out:
#   Branch  gross income
# 0      A         49.49
# 1      B         48.69
# 2      C         49.65

# %%
sns.barplot(x='Branch',y='gross income',data=df1)
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %%
#Multivarient analysis
sns.barplot(x='Branch',y='gross income',data=df,hue='City')
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %%
#Is there any relationship between gender and gross income?(Numerical-Categorical)
sns.barplot(x='Gender',y='gross income',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='gross income'>

# %%
sns.boxplot(x='Gender',y='gross income',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='gross income'>

# %%
sns.boxplot(x='Gender',y='gross income',data=df,hue='Customer type')
# Out:
# <Axes: xlabel='Gender', ylabel='gross income'>

# %%
#Find the product line that generates the most income.(Numerical-categorical)
df.head()
df.groupby('Product line')['gross income'].max()
# Out:
# Product line
# Electronic accessories    44.8785
# Fashion accessories       49.6500
# Food and beverages        49.2600
# Health and beauty         45.2500
# Home and lifestyle        48.7500
# Sports and travel         47.7200
# Name: gross income, dtype: float64

# %%
sns.barplot(x='Product line',y='gross income',data=df,color='pink')
plt.xticks(rotation=80)
plt.show()

# %%
#Find the highest unit price in the productline.(Numerical-Categorical)
df.groupby('Product line')['Unit price'].max()
# Out:
# Product line
# Electronic accessories    99.73
# Fashion accessories       99.89
# Food and beverages        99.79
# Health and beauty         99.96
# Home and lifestyle        99.92
# Sports and travel         99.96
# Name: Unit price, dtype: float64

# %%
sns.barplot(x='Product line',y='Unit price',data=df,color='pink')
plt.xticks(rotation=80)
plt.show()

# %%
#Find different payment methods used by Customers citywise.(Categorical-Categorical)
sns.countplot(x='Payment',hue='City',data=df)
# Out:
# <Axes: xlabel='Payment', ylabel='count'>

# %%
pd.crosstab(df['City'],df['Payment'])
# Out:
# Payment    Cash  Credit card  Ewallet
# City
# Mandalay    110          109      113
# Naypyitaw   124           98      106
# Yangon      110          104      126

# %%
sns.heatmap(pd.crosstab(df['City'],df['Payment']))
# Out:
# <Axes: xlabel='Payment', ylabel='City'>

# %%
#Which product line is purchased in the highest quantity?
df.head()
(df.groupby('Product line')['Quantity'].sum()).plot(kind='bar')
# Out:
# <Axes: xlabel='Product line'>

# %%
df.groupby('Product line')['Quantity'].sum()
# Out:
# Product line
# Electronic accessories    971
# Fashion accessories       902
# Food and beverages        952
# Health and beauty         854
# Home and lifestyle        911
# Sports and travel         920
# Name: Quantity, dtype: int64
